# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#!pip install citipy
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
from api_keys import weather_api_key
from api_keys import g_key


from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"  # "imperial" for Farenheit; "metric" for Celsius



# Build partial query URL
#query_url = base_url + "appid=" + weather_api_key + "&q=" + cityx
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

#create lists
x_city=[]
x_cloudiness=[]
x_country=[]
x_date=[]
x_humidity=[]
x_latitude=[]
x_longitude=[]
x_max_temp=[]
x_wind_speed=[]
record = 0
set = 1
weather_df=[]
print(f"Beginning Data Retrieval")
print(f"-------------------------------------------------")
for index in cities: #[0:55]:   #https://samples.openweathermap.org/data/2.5/find?q=London&units=metric&appid=439d4b804bc8187953eb36d2a8c26a02

    
    try:
        response = requests.get(query_url + index).json() #index is city name, passing to url
        
        x_cloudiness.append(response['clouds']['all'])    # append cloudiness list
        x_country.append(response['sys']['country'])      # append country list 
        x_date.append(response['dt'])                     # append date list 
        x_humidity.append(response['main']['humidity'])   # append humidity list
        x_latitude.append(response['coord']['lat'])       # apppend latitude list
        x_longitude.append(response['coord']['lon'])      # append longitude list
        x_max_temp.append(response['main']['temp_max'])   # append max temp list
        x_wind_speed.append(response['wind']['speed'])    # append wind speed list
        x_city.append(index)                              # append city list
        if(x_cloudiness != None):                   # Only insert cities to df with complete values such as Cloudiness
            weather_df.append({
                      "City": x_city,                           
                      "Cloudiness": x_cloudiness,
                      "Country": x_country,
                      "Date": x_date,
                      "Humidity": x_humidity,
                      "Lat": x_latitude,
                      "Lng": x_longitude,
                      "Max Temp": x_max_temp,
                      "Wind Speed": x_wind_speed})   
        
            print(f"Processing Record {record} of Set {set} | {index}") # print log
            record += 1                                                 # set "Record" counter   
            if (record == 50):
              record = 0
              set +=1                                                   # set "Set" counter 
            
   
        
    except:
        print("City not found. Skipping...") # If city is missing, print this"
        pass
      

print(f"------------------------------")
print(f"Data Retrieval Complete")
print(f"------------------------------")


# for p in x_city:
#      print(p)
# Out:
# Beginning Data Retrieval
# -------------------------------------------------
# Processing Record 0 of Set 1 | mataura
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | damietta
# Processing Record 3 of Set 1 | nang rong
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | victoria
# Processing Record 9 of Set 1 | lakatoro
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | upernavik
# Processing Record 13 of Set 1 | komsomolskiy
# Processing Record 14 of Set 1 | alma
# Processing Record 15 of Set 1 | los llanos de aridane
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | nelson bay
# Processing Record 18 of Set 1 | hovd
# City not found. Skipping...
# Processing Record 19 of Set 1 | nova olimpia
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | nishihara
# Processing Record 22 of Set 1 | sakakah
# Processing Record 23 of Set 1 | evensk
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | longyearbyen
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | avarua
# City not found. Skipping...
# Processing Record 28 of Set 1 | narsaq
# Processing Record 29 of Set 1 | saint-augustin
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | brewster
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | bredasdorp
# Processing Record 36 of Set 1 | zemio
# Processing Record 37 of Set 1 | sorong
# City not found. Skipping...
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | olafsvik
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | naze
# Processing Record 42 of Set 1 | guerrero negro
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | bilma
# City not found. Skipping...
# Processing Record 45 of Set 1 | dicabisagan
# Processing Record 46 of Set 1 | kaitangata
# Processing Record 47 of Set 1 | rio gallegos
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | sorland
# Processing Record 0 of Set 2 | mustafakemalpasa
# Processing Record 1 of Set 2 | chilca
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | ribeira grande
# Processing Record 4 of Set 2 | ostrovnoy
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | bundibugyo
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | dilla
# Processing Record 10 of Set 2 | ust-kan
# Processing Record 11 of Set 2 | touros
# Processing Record 12 of Set 2 | huarmey
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | churapcha
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | sitka
# Processing Record 17 of Set 2 | anadyr
# Processing Record 18 of Set 2 | torbay
# Processing Record 19 of Set 2 | usinsk
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | mashhad
# Processing Record 22 of Set 2 | norman wells
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | oshawa
# Processing Record 25 of Set 2 | manggar
# Processing Record 26 of Set 2 | san rafael
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | oktyabrskiy
# Processing Record 29 of Set 2 | honiara
# Processing Record 30 of Set 2 | fallon
# Processing Record 31 of Set 2 | wanning
# City not found. Skipping...
# Processing Record 32 of Set 2 | port moresby
# Processing Record 33 of Set 2 | raudeberg
# Processing Record 34 of Set 2 | jiexiu
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | wuchang
# Processing Record 37 of Set 2 | inhambane
# Processing Record 38 of Set 2 | payo
# Processing Record 39 of Set 2 | vardo
# Processing Record 40 of Set 2 | taoudenni
# Processing Record 41 of Set 2 | constitucion
# Processing Record 42 of Set 2 | semey
# City not found. Skipping...
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | shihezi
# Processing Record 45 of Set 2 | kargil
# Processing Record 46 of Set 2 | escanaba
# Processing Record 47 of Set 2 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 48 of Set 2 | bautzen
# Processing Record 49 of Set 2 | flin flon
# Processing Record 0 of Set 3 | port macquarie
# Processing Record 1 of Set 3 | talnakh
# Processing Record 2 of Set 3 | puerto quijarro
# City not found. Skipping...
# Processing Record 3 of Set 3 | iqaluit
# City not found. Skipping...
# Processing Record 4 of Set 3 | mao
# Processing Record 5 of Set 3 | khartoum
# Processing Record 6 of Set 3 | nanortalik
# Processing Record 7 of Set 3 | codrington
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | saint george
# Processing Record 10 of Set 3 | pisco
# Processing Record 11 of Set 3 | benxi
# Processing Record 12 of Set 3 | angoram
# Processing Record 13 of Set 3 | omsukchan
# Processing Record 14 of Set 3 | jamestown
# Processing Record 15 of Set 3 | mar del plata
# City not found. Skipping...
# Processing Record 16 of Set 3 | albina
# Processing Record 17 of Set 3 | bathsheba
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | chuy
# Processing Record 20 of Set 3 | martapura
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | khatanga
# Processing Record 23 of Set 3 | saint-georges
# Processing Record 24 of Set 3 | lewistown
# Processing Record 25 of Set 3 | muros
# Processing Record 26 of Set 3 | steamboat springs
# Processing Record 27 of Set 3 | abu dhabi
# Processing Record 28 of Set 3 | santa vitoria do palmar
# Processing Record 29 of Set 3 | mount isa
# Processing Record 30 of Set 3 | tiksi
# City not found. Skipping...
# Processing Record 31 of Set 3 | cap malheureux
# Processing Record 32 of Set 3 | kapit
# Processing Record 33 of Set 3 | poum
# Processing Record 34 of Set 3 | kulhudhuffushi
# Processing Record 35 of Set 3 | te anau
# Processing Record 36 of Set 3 | pangai
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | saint-gilles
# Processing Record 39 of Set 3 | port elizabeth
# Processing Record 40 of Set 3 | khani
# Processing Record 41 of Set 3 | arlit
# Processing Record 42 of Set 3 | hithadhoo
# Processing Record 43 of Set 3 | neuquen
# Processing Record 44 of Set 3 | shetpe
# Processing Record 45 of Set 3 | nome
# Processing Record 46 of Set 3 | lompoc
# Processing Record 47 of Set 3 | fort nelson
# Processing Record 48 of Set 3 | chippewa falls
# Processing Record 49 of Set 3 | blagoyevo
# Processing Record 0 of Set 4 | san quintin
# Processing Record 1 of Set 4 | umm lajj
# Processing Record 2 of Set 4 | vestmannaeyjar
# Processing Record 3 of Set 4 | san cristobal
# Processing Record 4 of Set 4 | sitrah
# Processing Record 5 of Set 4 | riyadh
# Processing Record 6 of Set 4 | ewa beach
# Processing Record 7 of Set 4 | brae
# Processing Record 8 of Set 4 | butaritari
# Processing Record 9 of Set 4 | bacolod
# Processing Record 10 of Set 4 | banyo
# City not found. Skipping...
# Processing Record 11 of Set 4 | provideniya
# Processing Record 12 of Set 4 | cabo san lucas
# Processing Record 13 of Set 4 | yatou
# Processing Record 14 of Set 4 | kutum
# Processing Record 15 of Set 4 | adrar
# City not found. Skipping...
# Processing Record 16 of Set 4 | vanimo
# Processing Record 17 of Set 4 | fortuna
# City not found. Skipping...
# Processing Record 18 of Set 4 | ayr
# Processing Record 19 of Set 4 | norsup
# Processing Record 20 of Set 4 | wallacetown
# Processing Record 21 of Set 4 | new norfolk
# Processing Record 22 of Set 4 | celestun
# Processing Record 23 of Set 4 | namibe
# Processing Record 24 of Set 4 | yenagoa
# City not found. Skipping...
# Processing Record 25 of Set 4 | cape coast
# Processing Record 26 of Set 4 | nikolskoye
# Processing Record 27 of Set 4 | kavieng
# City not found. Skipping...
# Processing Record 28 of Set 4 | georgiyevka
# Processing Record 29 of Set 4 | osakarovka
# City not found. Skipping...
# Processing Record 30 of Set 4 | chokwe
# Processing Record 31 of Set 4 | arcata
# Processing Record 32 of Set 4 | dragor
# Processing Record 33 of Set 4 | pangnirtung
# Processing Record 34 of Set 4 | teguldet
# Processing Record 35 of Set 4 | isangel
# Processing Record 36 of Set 4 | urumqi
# Processing Record 37 of Set 4 | luderitz
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 4 | tasiilaq
# Processing Record 39 of Set 4 | kirkenes
# Processing Record 40 of Set 4 | ballina
# Processing Record 41 of Set 4 | balakhninskiy
# Processing Record 42 of Set 4 | nueva concepcion
# Processing Record 43 of Set 4 | norfolk
# Processing Record 44 of Set 4 | loandjili
# Processing Record 45 of Set 4 | lumatil
# Processing Record 46 of Set 4 | finschhafen
# Processing Record 47 of Set 4 | mogadishu
# Processing Record 48 of Set 4 | biak
# Processing Record 49 of Set 4 | jacksonville
# Processing Record 0 of Set 5 | nguru
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | pravda
# Processing Record 3 of Set 5 | geraldton
# Processing Record 4 of Set 5 | luoyang
# Processing Record 5 of Set 5 | saldanha
# Processing Record 6 of Set 5 | chifeng
# Processing Record 7 of Set 5 | greenwood
# Processing Record 8 of Set 5 | flinders
# Processing Record 9 of Set 5 | airai
# City not found. Skipping...
# Processing Record 10 of Set 5 | sao filipe
# Processing Record 11 of Set 5 | iralaya
# Processing Record 12 of Set 5 | shellbrook
# Processing Record 13 of Set 5 | leningradskiy
# Processing Record 14 of Set 5 | cidreira
# City not found. Skipping...
# Processing Record 15 of Set 5 | palmer
# Processing Record 16 of Set 5 | aquiraz
# Processing Record 17 of Set 5 | ixtapa
# Processing Record 18 of Set 5 | shingu
# Processing Record 19 of Set 5 | maputo
# Processing Record 20 of Set 5 | kitimat
# Processing Record 21 of Set 5 | golden
# Processing Record 22 of Set 5 | kruisfontein
# City not found. Skipping...
# Processing Record 23 of Set 5 | bonavista
# Processing Record 24 of Set 5 | abu samrah
# Processing Record 25 of Set 5 | pachino
# Processing Record 26 of Set 5 | kankan
# Processing Record 27 of Set 5 | vernon
# Processing Record 28 of Set 5 | viedma
# Processing Record 29 of Set 5 | nuuk
# City not found. Skipping...
# Processing Record 30 of Set 5 | luganville
# Processing Record 31 of Set 5 | vostok
# Processing Record 32 of Set 5 | richards bay
# Processing Record 33 of Set 5 | comodoro rivadavia
# Processing Record 34 of Set 5 | havoysund
# Processing Record 35 of Set 5 | kotido
# Processing Record 36 of Set 5 | bandarbeyla
# Processing Record 37 of Set 5 | angoche
# Processing Record 38 of Set 5 | locri
# Processing Record 39 of Set 5 | sao jose da coroa grande
# Processing Record 40 of Set 5 | nantucket
# Processing Record 41 of Set 5 | bousse
# Processing Record 42 of Set 5 | dunedin
# Processing Record 43 of Set 5 | margate
# Processing Record 44 of Set 5 | red wing
# City not found. Skipping...
# Processing Record 45 of Set 5 | hamilton
# Processing Record 46 of Set 5 | abalak
# Processing Record 47 of Set 5 | boende
# Processing Record 48 of Set 5 | wanaka
# Processing Record 49 of Set 5 | sayyan
# Processing Record 0 of Set 6 | chipinge
# Processing Record 1 of Set 6 | fairbanks
# Processing Record 2 of Set 6 | sola
# City not found. Skipping...
# Processing Record 3 of Set 6 | synya
# Processing Record 4 of Set 6 | cherskiy
# Processing Record 5 of Set 6 | pervouralsk
# Processing Record 6 of Set 6 | coihaique
# Processing Record 7 of Set 6 | tessalit
# Processing Record 8 of Set 6 | aklavik
# Processing Record 9 of Set 6 | alta floresta
# Processing Record 10 of Set 6 | ust-nera
# City not found. Skipping...
# Processing Record 11 of Set 6 | gorontalo
# Processing Record 12 of Set 6 | polohy
# Processing Record 13 of Set 6 | sao joao da barra
# Processing Record 14 of Set 6 | manokwari
# Processing Record 15 of Set 6 | okhotsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 6 | galveston
# Processing Record 17 of Set 6 | hue
# Processing Record 18 of Set 6 | misratah
# Processing Record 19 of Set 6 | caravelas
# Processing Record 20 of Set 6 | mapiri
# Processing Record 21 of Set 6 | marsala
# City not found. Skipping...
# Processing Record 22 of Set 6 | akhtanizovskaya
# Processing Record 23 of Set 6 | myitkyina
# Processing Record 24 of Set 6 | port lincoln
# Processing Record 25 of Set 6 | lagoa
# Processing Record 26 of Set 6 | deneysville
# Processing Record 27 of Set 6 | varberg
# Processing Record 28 of Set 6 | boksitogorsk
# Processing Record 29 of Set 6 | marienburg
# Processing Record 30 of Set 6 | kenai
# Processing Record 31 of Set 6 | macas
# Processing Record 32 of Set 6 | istisu
# Processing Record 33 of Set 6 | ilo
# Processing Record 34 of Set 6 | joshimath
# Processing Record 35 of Set 6 | ornskoldsvik
# Processing Record 36 of Set 6 | kawalu
# Processing Record 37 of Set 6 | englewood
# City not found. Skipping...
# Processing Record 38 of Set 6 | kushima
# Processing Record 39 of Set 6 | salalah
# Processing Record 40 of Set 6 | ijui
# Processing Record 41 of Set 6 | cayenne
# Processing Record 42 of Set 6 | parrita
# Processing Record 43 of Set 6 | wonthaggi
# Processing Record 44 of Set 6 | aban
# Processing Record 45 of Set 6 | dom pedro
# Processing Record 46 of Set 6 | yulara
# Processing Record 47 of Set 6 | katsuura
# Processing Record 48 of Set 6 | nouadhibou
# Processing Record 49 of Set 6 | calvinia
# Processing Record 0 of Set 7 | meulaboh
# Processing Record 1 of Set 7 | faanui
# Processing Record 2 of Set 7 | nakambala
# Processing Record 3 of Set 7 | jadu
# Processing Record 4 of Set 7 | tukrah
# Processing Record 5 of Set 7 | berlevag
# Processing Record 6 of Set 7 | clyde river
# City not found. Skipping...
# Processing Record 7 of Set 7 | maldonado
# Processing Record 8 of Set 7 | esperance
# Processing Record 9 of Set 7 | wewak
# Processing Record 10 of Set 7 | port blair
# Processing Record 11 of Set 7 | itoman
# Processing Record 12 of Set 7 | lata
# Processing Record 13 of Set 7 | faya
# Processing Record 14 of Set 7 | la ligua
# Processing Record 15 of Set 7 | bengkulu
# Processing Record 16 of Set 7 | northam
# Processing Record 17 of Set 7 | north bend
# Processing Record 18 of Set 7 | yerbogachen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 7 | nuristan
# Processing Record 20 of Set 7 | menongue
# Processing Record 21 of Set 7 | safaga
# Processing Record 22 of Set 7 | ponta do sol
# Processing Record 23 of Set 7 | tartagal
# Processing Record 24 of Set 7 | iturama
# Processing Record 25 of Set 7 | limenaria
# Processing Record 26 of Set 7 | robertsport
# City not found. Skipping...
# Processing Record 27 of Set 7 | hambantota
# Processing Record 28 of Set 7 | anloga
# Processing Record 29 of Set 7 | laguna
# Processing Record 30 of Set 7 | council bluffs
# Processing Record 31 of Set 7 | samaipata
# Processing Record 32 of Set 7 | souillac
# Processing Record 33 of Set 7 | mizdah
# Processing Record 34 of Set 7 | abengourou
# Processing Record 35 of Set 7 | rawson
# Processing Record 36 of Set 7 | yima
# Processing Record 37 of Set 7 | harper
# Processing Record 38 of Set 7 | port hueneme
# Processing Record 39 of Set 7 | kahului
# Processing Record 40 of Set 7 | otavi
# City not found. Skipping...
# Processing Record 41 of Set 7 | chake chake
# Processing Record 42 of Set 7 | udachnyy
# Processing Record 43 of Set 7 | beloha
# Processing Record 44 of Set 7 | la rioja
# Processing Record 45 of Set 7 | iquique
# Processing Record 46 of Set 7 | gat
# Processing Record 47 of Set 7 | maple creek
# City not found. Skipping...
# Processing Record 48 of Set 7 | alofi
# Processing Record 49 of Set 7 | pedernales
# Processing Record 0 of Set 8 | panaba
# Processing Record 1 of Set 8 | merauke
# Processing Record 2 of Set 8 | kokstad
# City not found. Skipping...
# Processing Record 3 of Set 8 | ilulissat
# Processing Record 4 of Set 8 | sydney
# City not found. Skipping...
# Processing Record 5 of Set 8 | port shepstone
# Processing Record 6 of Set 8 | oranjemund
# Processing Record 7 of Set 8 | kununurra
# Processing Record 8 of Set 8 | cururupu
# Processing Record 9 of Set 8 | katobu
# Processing Record 10 of Set 8 | diego de almagro
# Processing Record 11 of Set 8 | tafalla
# Processing Record 12 of Set 8 | muzhi
# Processing Record 13 of Set 8 | diamantino
# Processing Record 14 of Set 8 | ardmore
# Processing Record 15 of Set 8 | klaksvik
# City not found. Skipping...
# Processing Record 16 of Set 8 | sokoni
# Processing Record 17 of Set 8 | pacasmayo
# Processing Record 18 of Set 8 | bulgan
# Processing Record 19 of Set 8 | kurumkan
# Processing Record 20 of Set 8 | tete
# Processing Record 21 of Set 8 | chelno-vershiny
# Processing Record 22 of Set 8 | bubaque
# Processing Record 23 of Set 8 | muroto
# Processing Record 24 of Set 8 | tommot
# City not found. Skipping...
# Processing Record 25 of Set 8 | mayumba
# Processing Record 26 of Set 8 | mehamn
# Processing Record 27 of Set 8 | requena
# Processing Record 28 of Set 8 | liberal
# Processing Record 29 of Set 8 | asau
# Processing Record 30 of Set 8 | yar-sale
# Processing Record 31 of Set 8 | codajas
# Processing Record 32 of Set 8 | victor harbor
# Processing Record 33 of Set 8 | kepno
# Processing Record 34 of Set 8 | santa cruz
# City not found. Skipping...
# Processing Record 35 of Set 8 | marsh harbour
# City not found. Skipping...
# Processing Record 36 of Set 8 | manakara
# Processing Record 37 of Set 8 | krasnoselkup
# Processing Record 38 of Set 8 | ageyevo
# Processing Record 39 of Set 8 | manono
# City not found. Skipping...
# Processing Record 40 of Set 8 | juneau
# Processing Record 41 of Set 8 | auki
# Processing Record 42 of Set 8 | keuruu
# Processing Record 43 of Set 8 | kloulklubed
# Processing Record 44 of Set 8 | nacala
# Processing Record 45 of Set 8 | southbridge
# Processing Record 46 of Set 8 | itarema
# Processing Record 47 of Set 8 | batemans bay
# Processing Record 48 of Set 8 | takoradi
# Processing Record 49 of Set 8 | qasigiannguit
# Processing Record 0 of Set 9 | ahipara
# Processing Record 1 of Set 9 | turukhansk
# Processing Record 2 of Set 9 | mount gambier
# Processing Record 3 of Set 9 | bagan
# Processing Record 4 of Set 9 | proti
# Processing Record 5 of Set 9 | cabedelo
# Processing Record 6 of Set 9 | aksu
# Processing Record 7 of Set 9 | shimoda
# Processing Record 8 of Set 9 | quatre cocos
# Processing Record 9 of Set 9 | soyo
# Processing Record 10 of Set 9 | pevek
# Processing Record 11 of Set 9 | cordoba
# Processing Record 12 of Set 9 | saryozek
# Processing Record 13 of Set 9 | ketchikan
# Processing Record 14 of Set 9 | houma
# Processing Record 15 of Set 9 | saskylakh
# Processing Record 16 of Set 9 | boa vista
# Processing Record 17 of Set 9 | roxana
# Processing Record 18 of Set 9 | kemijarvi
# Processing Record 19 of Set 9 | tadine
# Processing Record 20 of Set 9 | san pedro
# Processing Record 21 of Set 9 | tuatapere
# Processing Record 22 of Set 9 | sinnar
# Processing Record 23 of Set 9 | najran
# Processing Record 24 of Set 9 | abu kamal
# Processing Record 25 of Set 9 | la ronge
# Processing Record 26 of Set 9 | waynesboro
# Processing Record 27 of Set 9 | omboue
# Processing Record 28 of Set 9 | bedele
# Processing Record 29 of Set 9 | andros town
# Processing Record 30 of Set 9 | awjilah
# Processing Record 31 of Set 9 | makaha
# Processing Record 32 of Set 9 | samarai
# Processing Record 33 of Set 9 | silva jardim
# Processing Record 34 of Set 9 | pochutla
# Processing Record 35 of Set 9 | middleton
# Processing Record 36 of Set 9 | lufilufi
# Processing Record 37 of Set 9 | nisia floresta
# City not found. Skipping...
# Processing Record 38 of Set 9 | vilhena
# Processing Record 39 of Set 9 | qandala
# Processing Record 40 of Set 9 | sisimiut
# Processing Record 41 of Set 9 | tahoua
# Processing Record 42 of Set 9 | kieta
# City not found. Skipping...
# Processing Record 43 of Set 9 | volksrust
# Processing Record 44 of Set 9 | vytegra
# Processing Record 45 of Set 9 | kajaani
# Processing Record 46 of Set 9 | port augusta
# Processing Record 47 of Set 9 | gizo
# Processing Record 48 of Set 9 | soubre
# Processing Record 49 of Set 9 | yokadouma
# Processing Record 0 of Set 10 | mahibadhoo
# City not found. Skipping...
# Processing Record 1 of Set 10 | mindelo
# Processing Record 2 of Set 10 | sandane
# Processing Record 3 of Set 10 | port hardy
# Processing Record 4 of Set 10 | palmas
# Processing Record 5 of Set 10 | kuusamo
# Processing Record 6 of Set 10 | ancud
# Processing Record 7 of Set 10 | pangody
# Processing Record 8 of Set 10 | bayanday
# Processing Record 9 of Set 10 | kimbe
# Processing Record 10 of Set 10 | catamarca
# Processing Record 11 of Set 10 | coquimbo
# Processing Record 12 of Set 10 | tsuruga
# Processing Record 13 of Set 10 | mahanoro
# City not found. Skipping...
# Processing Record 14 of Set 10 | jimo
# Processing Record 15 of Set 10 | saint-francois
# Processing Record 16 of Set 10 | vysotskoye
# Processing Record 17 of Set 10 | foundiougne
# Processing Record 18 of Set 10 | waipawa
# Processing Record 19 of Set 10 | albury
# City not found. Skipping...
# Processing Record 20 of Set 10 | garowe
# Processing Record 21 of Set 10 | goderich
# Processing Record 22 of Set 10 | lorengau
# Processing Record 23 of Set 10 | gushi
# Processing Record 24 of Set 10 | henties bay
# Processing Record 25 of Set 10 | shahabad
# Processing Record 26 of Set 10 | novyy yarychiv
# Processing Record 27 of Set 10 | verkh-usugli
# Processing Record 28 of Set 10 | kisangani
# Processing Record 29 of Set 10 | pinega
# Processing Record 30 of Set 10 | uige
# Processing Record 31 of Set 10 | hutang
# Processing Record 32 of Set 10 | acapulco
# Processing Record 33 of Set 10 | cuamba
# Processing Record 34 of Set 10 | namatanai
# Processing Record 35 of Set 10 | coahuayana
# Processing Record 36 of Set 10 | warmbad
# Processing Record 37 of Set 10 | lamu
# Processing Record 38 of Set 10 | olinda
# City not found. Skipping...
# Processing Record 39 of Set 10 | commerce
# Processing Record 40 of Set 10 | halifax
# Processing Record 41 of Set 10 | ikom
# Processing Record 42 of Set 10 | valparaiso
# Processing Record 43 of Set 10 | port hedland
# Processing Record 44 of Set 10 | preston
# Processing Record 45 of Set 10 | haines junction
# Processing Record 46 of Set 10 | kodinsk
# Processing Record 47 of Set 10 | kortkeros
# Processing Record 48 of Set 10 | padang
# Processing Record 49 of Set 10 | fenoarivo
# Processing Record 0 of Set 11 | pattani
# Processing Record 1 of Set 11 | surt
# Processing Record 2 of Set 11 | elko
# Processing Record 3 of Set 11 | russell
# Processing Record 4 of Set 11 | saint anthony
# Processing Record 5 of Set 11 | killin
# Processing Record 6 of Set 11 | sabang
# Processing Record 7 of Set 11 | avera
# Processing Record 8 of Set 11 | kachiry
# Processing Record 9 of Set 11 | tura
# Processing Record 10 of Set 11 | pita
# Processing Record 11 of Set 11 | praia
# Processing Record 12 of Set 11 | dakar
# Processing Record 13 of Set 11 | aswan
# Processing Record 14 of Set 11 | tres lagoas
# Processing Record 15 of Set 11 | ellesmere port
# Processing Record 16 of Set 11 | san patricio
# Processing Record 17 of Set 11 | dingle
# Processing Record 18 of Set 11 | grand gaube
# Processing Record 19 of Set 11 | ovalle
# Processing Record 20 of Set 11 | kuybyshevo
# Processing Record 21 of Set 11 | lavrentiya
# Processing Record 22 of Set 11 | bucyrus
# Processing Record 23 of Set 11 | businga
# Processing Record 24 of Set 11 | bitung
# Processing Record 25 of Set 11 | sterling
# Processing Record 26 of Set 11 | nemuro
# Processing Record 27 of Set 11 | puerto ayacucho
# City not found. Skipping...
# Processing Record 28 of Set 11 | trelew
# Processing Record 29 of Set 11 | santa cruz cabralia
# City not found. Skipping...
# Processing Record 30 of Set 11 | roebourne
# Processing Record 31 of Set 11 | gazanjyk
# Processing Record 32 of Set 11 | zhezkazgan
# Processing Record 33 of Set 11 | beringovskiy
# Processing Record 34 of Set 11 | kemi
# Processing Record 35 of Set 11 | altay
# Processing Record 36 of Set 11 | kijang
# Processing Record 37 of Set 11 | kokopo
# Processing Record 38 of Set 11 | husavik
# Processing Record 39 of Set 11 | ulladulla
# Processing Record 40 of Set 11 | idrinskoye
# Processing Record 41 of Set 11 | alyangula
# Processing Record 42 of Set 11 | tazovskiy
# Processing Record 43 of Set 11 | bagdarin
# Processing Record 44 of Set 11 | boat of garten
# Processing Record 45 of Set 11 | gejiu
# Processing Record 46 of Set 11 | kota kinabalu
# City not found. Skipping...
# Processing Record 47 of Set 11 | bermeo
# Processing Record 48 of Set 11 | casma
# Processing Record 49 of Set 11 | ntungamo
# Processing Record 0 of Set 12 | saint-joseph
# Processing Record 1 of Set 12 | linxia
# Processing Record 2 of Set 12 | rudnogorsk
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# print(x_city)
# print("cloud")
# print(x_cloudiness)

# Adding data list to dataframe
weather_df = {
    "City": x_city,                          
    "Cloudiness": x_cloudiness,
    "Country": x_country,
    "Date": x_date,
    "Humidity": x_humidity,
    "Lat": x_latitude,
    "Lng": x_longitude,
    "Max Temp": x_max_temp,
    "Wind Speed": x_wind_speed
}
weather_data = pd.DataFrame(weather_df) 
weather_data.count()  # Count dataframe to check length
# Out:
# City          553
# Cloudiness    553
# Country       553
# Date          553
# Humidity      553
# Lat           553
# Lng           553
# Max Temp      553
# Wind Speed    553
# dtype: int64

# %%
weather_data.to_csv(output_data_file, encoding="utf-8", index=False) #Export city dataframe to csv file 
weather_data
# Out:
#                City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           mataura         100      NZ  1586927996        89 -46.19  168.86
# 1      puerto ayora          98      EC  1586928055        92  -0.74  -90.35
# 2          damietta           0      EG  1586928056        82  31.42   31.81
# 3         nang rong          20      TH  1586928056        47  14.64  102.79
# 4    saint-philippe          10      RE  1586927821        69 -21.36   55.77
# ..              ...         ...     ...         ...       ...    ...     ...
# 548           casma         100      CL  1586928145        93 -41.01  -73.12
# 549        ntungamo          72      UG  1586928146        52  -0.88   29.65
# 550    saint-joseph           8      RE  1586927933        69 -21.37   55.62
# 551          linxia           4      CN  1586927978        10  35.60  103.21
# 552      rudnogorsk           0      RU  1586928146        43  57.26  103.75
#
#      Max Temp  Wind Speed
# 0       48.99        5.01
# 1       79.00        3.00
# 2       62.60        8.05
# 3       95.00        4.70
# 4       82.99       25.28
# ..        ...         ...
# 548     53.60        3.36
# 549     72.09        1.23
# 550     82.99       25.28
# 551     71.37        5.88
# 552     52.70        1.81
#
# [553 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for City Latitude vs. Max Temperature
now = datetime.datetime.now()
analysis_date= now.strftime("%m/%d/%y")

plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o",color='dodgerblue', edgecolor='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature" + " (" + str(analysis_date) + ")")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_data/Latitude vs. Temperature Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for City Latitude vs. Humidity

plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o",color='dodgerblue', edgecolor='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity" + " (" + str(analysis_date) + ")")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_data/Latitude vs. Humidity Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for City Latitude vs. Cloudiness

plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o",color='dodgerblue', edgecolor='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness" + " (" + str(analysis_date) + ")")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_data/Latitude vs. Cloudiness Plot.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for City Latitude vs. Wind Speed

plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o",color='dodgerblue', edgecolor='black')

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed" + " (" + str(analysis_date) + ")")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_data/Latitude vs. Wind Speed.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = (weather_data[weather_data['Lat'] >= 0])

southern_df = (weather_data[weather_data['Lat'] < 0])
southern_df
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0            mataura         100      NZ  1586927996        89 -46.19  168.86
# 1       puerto ayora          98      EC  1586928055        92  -0.74  -90.35
# 4     saint-philippe          10      RE  1586927821        69 -21.36   55.77
# 6    bambous virieux          75      MU  1586927995        78 -20.34   57.76
# 9           lakatoro          75      VU  1586928056        74 -16.10  167.42
# ..               ...         ...     ...         ...       ...    ...     ...
# 539        ulladulla          49      AU  1586928144        42 -35.35  150.47
# 541        alyangula          75      AU  1586928144        59 -13.85  136.42
# 548            casma         100      CL  1586928145        93 -41.01  -73.12
# 549         ntungamo          72      UG  1586928146        52  -0.88   29.65
# 550     saint-joseph           8      RE  1586927933        69 -21.37   55.62
#
#      Max Temp  Wind Speed
# 0       48.99        5.01
# 1       79.00        3.00
# 4       82.99       25.28
# 6       79.00       17.22
# 9       84.20        8.05
# ..        ...         ...
# 539     80.60        9.17
# 541     89.60        8.05
# 548     53.60        3.36
# 549     72.09        1.23
# 550     82.99       25.28
#
# [195 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = northern_df['Lat']
y_values = northern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
x= northern_df['Lat'].min()                           # get min x_value
y= northern_df['Max Temp'].min()                      # get min y_value
plt.annotate(line_eq,( x, y),fontsize=15,color="red") # format annotation to be within intercept
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-squared is: 0.7601772017160657

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Add the linear regression equation and line to plot
x_values = southern_df['Lat']
y_values = southern_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
x= southern_df['Lat'].min()                           # get min x_value
y= southern_df['Max Temp'].min()                      # get min y_value
plt.annotate(line_eq,( x, y),fontsize=15,color="red") # format annotation to be within intercept
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
#plt.axis([0,100,-60,10]) #x axis min and max; y axix min and ma
plt.show()
# Out:
# The r-squared is: 0.46673225507466476

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
# Add the linear regression equation and line to plot
x_values = northern_df['Lat']
y_values = northern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
x= northern_df['Lat'].min()                            # get min x_value 
y= northern_df['Humidity'].min()                      # get min y_value 
plt.annotate(line_eq,( x, y),fontsize=15,color="red") # format annotation to be within intercept
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-squared is: 0.07431776890114744

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
# Add the linear regression equation and line to plot
x_values = southern_df['Lat']
y_values = southern_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
x= southern_df['Lat'].min()                            # get min x_value
y= southern_df['Humidity'].min()                       # get min y_value
plt.annotate(line_eq,( x, y),fontsize=15,color="red") # format annotation to be within intercept
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-squared is: 0.013270559641120724

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
# Add the linear regression equation and line to plot
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
x= northern_df['Lat'].min()                           # get min x_value
y= northern_df['Cloudiness'].min()                    # get min y_value 
plt.annotate(line_eq,( x, y),fontsize=15,color="red") # format annotation to be within intercept
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-squared is: 0.031067925398991014

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
# Add the linear regression equation and line to plot
x_values = southern_df['Lat']
y_values = southern_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) 
print(f"The r-squared is: {rvalue**2}") 
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
x= southern_df['Lat'].min()                           # get min x_value
y= southern_df['Cloudiness'].min()                    # get min y_value
plt.annotate(line_eq,( x, y),fontsize=15,color="red") # format annotation to be within intercept
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-squared is: 2.70910858283178e-05

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# Add the linear regression equation and line to plot
x_values = northern_df['Lat']
y_values = northern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"The r-squared is: {rvalue**2}") 
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
x= northern_df['Lat'].min()                           # get min x_value
y= northern_df['Wind Speed'].min()                    # get min y_value
plt.annotate(line_eq,( x, y),fontsize=15,color="red") # format annotation to be within intercept
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
# Out:
# The r-squared is: 0.05398798677600347

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# Add the linear regression equation and line to plot
x_values = southern_df['Lat']
y_values = southern_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) 
print(f"The r-squared is: {rvalue**2}") 
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
x= southern_df['Lat'].min()                           # get min x_value  
y= southern_df['Wind Speed'].min()                    # get min y_value
plt.annotate(line_eq,( x, y),fontsize=15,color="red") # format annotation to be within intercept
plt.ylabel('Wind Speed')
plt.show()
# Out:
# The r-squared is: 0.05689062508030925
